# %% [markdown]
# # Experiment set 2

# %% [markdown]
# MODIS example

# %% [markdown]
# Make sure to import prosail_fortran from:
#
# https://github.com/jgomezdans/prosail

# %% [markdown]
# Load the required files -- utils contains the core helper utilities used in the first experiment, tidied up a bit.

# %%
from pylab import *
from prosail_fortran import run_prosail
import numpy as np
from GaussianProcess import GaussianProcess
from utils import *

# %%
import pickle
# full sprectum
sensor = 'FullSpectrum'
bands = None
thresh = 0.98
n = 300
vza = 0.
sza = 45.
raa = 0.

lutfile = 'lutTest_Thresh_%.3f_n_%d_vza_%.2f_sza_%.2f_raa_%.2f_%s.npz'%(thresh,n,vza,sza,raa,sensor)
pickleFile = 'lutTest_Thresh_%.3f_n_%d_vza_%.2f_sza_%.2f_raa_%.2f_%s.pkl'%(thresh,n,vza,sza,raa,sensor)

try:
  gps = pickle.load(open(pickleFile,'rb'))
  npzfile = np.load(lutfile)
  angles,train_params,train_brf = npzfile['angles'],npzfile['train_params'],npzfile['train_brf']
  theta_min0,theta_min1 = npzfile['theta_min0'],npzfile['theta_min1']
  s,SB,train_SB,wl = npzfile['s'],npzfile['SB'],npzfile['train_SB'],npzfile['wl']
  inputs_t,keys = unpack(train_params.tolist())
  readLUT = True
  print 'Read lutfile %s and %s'%(lutfile,pickleFile)
  print 'number of EOFs %d'%len(gps)
except:
  readLUT = False
  print 'Failed to read lutfile %s and %s'%(lutfile,pickleFile)
  angles,train_params,train_brf,wl = lut(n,bands=bands,vza=vza,sza=sza,raa=raa)
  # spectral reduction
  U, s, V = np.linalg.svd(train_brf, full_matrices=True)
  wt = s.cumsum()/s.sum()
  ww = np.where(wt<=thresh)
  SB = V[ww[0],:]

  # now project the training data onto these axes
  train_SB = np.dot(train_brf,SB.T).T

  # unpack params
  inputs_t,keys = unpack(train_params)

  # set some arrays to collect information
  gps = ['']*train_SB.shape[0]
  theta_min0 = ['']*train_SB.shape[0]
  theta_min1 = ['']*train_SB.shape[0]

  # loop over each dimenstion and train a gp
  for i in xrange(train_SB.shape[0]):
    print 'doing PC %d'%i   
    yields_t = train_SB[i]
    gps[i] = GaussianProcess ( inputs_t, yields_t )
    theta_min0[i], theta_min1[i] = gps[i].learn_hyperparameters (n_tries=2)

  pickle.dump(gps,open(pickleFile,'wb'))
  np.savez(lutfile,angles=angles,train_params=train_params,\
                  train_brf=train_brf,\
                  theta_min0=theta_min0,theta_min1=theta_min1,\
                  s=s,SB=SB,train_SB=train_SB,wl=wl)
# Out:
# Read lutfile lutTest_Thresh_0.980_n_300_vza_0.00_sza_45.00_raa_0.00_FullSpectrum.npz and lutTest_Thresh_0.980_n_300_vza_0.00_sza_45.00_raa_0.00_FullSpectrum.pkl
# number of EOFs 8

# %%
plt.clf()
for i in xrange(train_SB.shape[0]):
  plt.plot(wl,SB[i],label='PC %d (%.2f)'%(i,(s/s.sum())[i]))

plt.legend(prop={'size':7})
plt.xlim(wl.min(),wl.max())
plt.show()

# %%
# now look at e.g. reflectance as a function of LAI
(pmin,pmax) = limits()

xlais = np.arange(pmin['xlai'],pmax['xlai'],0.1)
ones = np.ones_like(xlais)
params = {}
for i in pmin.keys():
  params.update(invtransform({i:ones*(pmin[i]+pmax[i])*0.5}))
params.update(invtransform({'xlai':xlais}))

# now run true model
brdf,wl = brdfModel(params,vza,sza,raa)[-2:]
# now emulate (dont forget to transform!)
inputs,keys = unpack(transform(params))
brdfe = reconstruct(gps,SB,inputs)
plt.clf()
plt.plot(np.array([wl]*10).T,brdf.T,'k-')
plt.plot(np.array([wl]*10).T,brdfe.T,'r--')
plt.xlim(wl[0],wl[-1])
plt.xlabel('wavelength (nm)')
plt.ylabel('reflectance')
plt.title('true (black) and emulated (red) reflectance for varying LAI')
plt.show()

# %%
##### We now generate an independent dataset and use that for testing the GP

angles,test_params,test_brf,wl = lut(n,bands=bands)
test_SB = np.dot(test_brf,SB.T).T

# unpack params
inputs_v,keys = unpack(test_params)

plt.clf()
# loop over each dimenstion and test a gp
for i in xrange(train_SB.shape[0]):
  # This is the set of true projected parameters
  yields_v = test_SB[i]
  # This is what we predict from the emulator
  pred_mu, pred_var, deriv  = gps[i].predict ( inputs_v )

  plt.plot(yields_v,pred_mu,'+',label='PC %d'%i)

plt.legend(loc='best',prop={'size':8})
plt.show()

# %%
# Now look at some example reconstructions

fwd = reconstruct(gps,SB,inputs_v)

i = 0
true = test_brf[i]
em = fwd[i]
plt.clf()
plt.plot(wl,true,'k-')
plt.plot(wl,em,'r+')

plt.xlabel('wavelength (nm)')
plt.ylabel('reflectance')
plt.show()

# %%
i = 50
true = test_brf[i]
em = fwd[i]
plt.clf()
plt.plot(wl,true,'k-')
plt.plot(wl,em,'r+')

plt.xlabel('wavelength (nm)')
plt.ylabel('reflectance')
plt.show()

# %%
i = 100
true = test_brf[i]
em = fwd[i]
plt.clf()
plt.plot(wl,true,'k-')
plt.plot(wl,em,'r+')

plt.xlabel('wavelength (nm)')
plt.ylabel('reflectance')
plt.show()

# %%
def funcd(params,brf,SB,gps):
  fwd,derivs = reconstructD(gps,SB,params)
  obs = brf
  d = (fwd - obs)
  Jprime = np.matrix(d) * np.matrix(derivs).T
  e = np.sum(d*d)
  return 0.5*e,Jprime.T

# function to do the minimisation in EOF space
def funcd2(params,projectedBrf,gps):
  params = np.atleast_2d(np.array(params))
  e = 0.
  Jprime = np.zeros_like(params)
  for i in xrange(len(gps)):
    fwd,sd,deriv = gps[i].predict(params)
    d = (fwd[0] - projectedBrf[i]) # /sd[0]
    Jprime += d*deriv
    e += d*d
  return 0.5*e,Jprime

def solver(i,x,test_brf,SB,gps,b,keys,inputs_v=None,noshow=True,noplot=False):
  from  scipy.optimize import fmin_l_bfgs_b

  params,f,d = fmin_l_bfgs_b(funcd,x,bounds=b,factr=1.0,pgtol=1e-20,args=(test_brf[i],SB,gps),iprint=0)
    
  if not noplot:
    fwd = reconstruct(gps,SB,params)[0]
    plt.clf()
    plt.plot(wl,fwd,'r+')
    plt.plot(wl,test_brf[i],'k-')
    if not noshow:
      plt.show()
    print 'parameters1: ',invtransform(pack(params,keys))
    if not noshow:
      print 'true       : ',invtransform(pack(inputs_v[i],keys))
  return invtransform(pack(params,keys)),f,d

def solver2(i,test_SB,gps,b,x=None,train_SB=None,inputs_v=None,noshow=True,noplot=False):
  from  scipy.optimize import fmin_l_bfgs_b
  import sys
  if train_SB != None:
    dd = (train_SB.T - test_SB[i]) **2
    e = np.sum(dd,axis=1)
    ww = np.where(e == e.min())[0]
    x = np.array([inputs_t[ww,j] for j in xrange(len(keys))]).flatten()
    #print>> sys.stderr,'Internal initial state set to',x
    #print>> sys.stderr,invtransform(pack(x,keys))
  params,f,d = fmin_l_bfgs_b(funcd2,x,bounds=b,factr=1.0,pgtol=1e-20,args=(test_SB[i],gps),iprint=0)
  if not noplot:
    if not noshow:
      plt.clf()
    fwd = reconstruct(gps,SB,params)[0]
    plt.plot(wl,fwd,'g+')
    if not noshow:
      plt.plot(wl,test_brf[i],'k-')
    plt.show()
    print 'parameters2: ',invtransform(pack(params,keys))
    print 'true       : ',invtransform(pack(inputs_v[i],keys))
  return invtransform(pack(params,keys)),f,d

# %%
# We now attempt to use the emulator to solve inverse problems (ultimately to allow fast data assimilation).
# form the state vector

(pmin,pmax) = limits()
keys = np.sort(pmin.keys())
ppmin = unpack(pmin)[0]
ppmax = unpack(pmax)[0]

b = [(ppmin[i],ppmax[i]) for i in xrange(len(keys))]
x = []
for k in keys:
  x.append((pmin[k]+pmax[k])*0.5)


# project the test_brf data
test_SB = np.dot(test_brf,SB.T)
solver2(0,test_SB,gps,b,train_SB=train_SB,inputs_v=inputs_v,noshow=False)
# Out:
# parameters2:  {'bsoil': 1.3155084770216099, 'lai': 3.3049502788162717, 'cm': 0.0022159665772263225, 'car': 15.750764630786465, 'n': 1.7083498485807171, 'cbrown': 0.44274362352977864, 'psoil': 0.67741825405366041, 'cab': 23.544292955668002, 'ala': 55.514295619984573, 'cw': 0.031478449187778659, 'hspot': 0.61492878570736709}
# true       :  {'bsoil': 1.9549744115959831, 'lai': 3.3190902086039205, 'cm': 0.0031224871356281166, 'car': 19.485074538933876, 'n': 1.9208228012602995, 'cbrown': 0.48614677541373197, 'psoil': 0.82568681737017513, 'cab': 26.303140304498029, 'ala': 53.499520087217228, 'cw': 0.034074908118299219, 'hspot': 0.44563549212632086}
# ({'ala': 55.514295619984573,
#   'bsoil': 1.3155084770216099,
#   'cab': 23.544292955668002,
#   'car': 15.750764630786465,
#   'cbrown': 0.44274362352977864,
#   'cm': 0.0022159665772263225,
#   'cw': 0.031478449187778659,
#   'hspot': 0.61492878570736709,
#   'lai': 3.3049502788162717,
#   'n': 1.7083498485807171,
#   'psoil': 0.67741825405366041},
#  9.3350010117427395e-18,
#  {'funcalls': 142,
#   'grad': array([[  5.39850629e-13,  -8.38000605e-10,   9.49851527e-10,
#           1.45716703e-09,  -2.72860555e-11,  -1.39849722e-08,
#           8.30401408e-09,   8.74770101e-10,   2.82473824e-09,
#          -6.30604477e-09,  -1.78659874e-08]]),
#   'task': 'CONVERGENCE: REL_REDUCTION_OF_F <= FACTR*EPSMCH',
#   'warnflag': 0})

# %%
solver2(25,test_SB,gps,b,inputs_v=inputs_v,noshow=False,train_SB=train_SB)
# Out:
# parameters2:  {'bsoil': 0.85935016802719333, 'lai': 7.7819235750844005, 'cm': 0.0026423431656186864, 'car': 12.130635452640838, 'n': 2.3696725510633367, 'cbrown': 0.46954699777690662, 'psoil': 0.81476616739552032, 'cab': 26.117294642953521, 'ala': 80.125343757661568, 'cw': 0.021521810608800453, 'hspot': 0.091178774450579897}
# true       :  {'bsoil': 1.163664974843609, 'lai': 6.7316735237784115, 'cm': 0.0023193754529823004, 'car': 11.214260015075904, 'n': 1.5386184277499415, 'cbrown': 0.39109316937992422, 'psoil': 0.066639295144892419, 'cab': 24.924290922046531, 'ala': 80.475456773524272, 'cw': 0.019926541227383514, 'hspot': 0.2648242690418649}
# ({'ala': 80.125343757661568,
#   'bsoil': 0.85935016802719333,
#   'cab': 26.117294642953521,
#   'car': 12.130635452640838,
#   'cbrown': 0.46954699777690662,
#   'cm': 0.0026423431656186864,
#   'cw': 0.021521810608800453,
#   'hspot': 0.091178774450579897,
#   'lai': 7.7819235750844005,
#   'n': 2.3696725510633367,
#   'psoil': 0.81476616739552032},
#  6.5760132918362356e-17,
#  {'funcalls': 187,
#   'grad': array([[  1.64973841e-11,  -1.19087042e-08,  -1.36297116e-09,
#          -1.25617057e-09,  -5.43859863e-11,   1.49271715e-08,
#          -2.80250622e-09,  -4.08262504e-09,  -9.91892825e-10,
#          -1.36236383e-08,  -1.89280683e-09]]),
#   'task': 'CONVERGENCE: REL_REDUCTION_OF_F <= FACTR*EPSMCH',
#   'warnflag': 0})

# %%
solver2(50,test_SB,gps,b,inputs_v=inputs_v,noshow=False,train_SB=train_SB)
# Out:
# parameters2:  {'bsoil': 0.92780684178522754, 'lai': 2.5122937629895548, 'cm': 0.0063385285096441693, 'car': 1.5491913898521137, 'n': 1.212666645702644, 'cbrown': 0.83771753093482726, 'psoil': 0.59917775441340604, 'cab': 49.762985062280976, 'ala': 21.811746512275406, 'cw': 0.010007018716533159, 'hspot': 0.99899999477752843}
# true       :  {'bsoil': 1.4645915882106337, 'lai': 2.4594155142420764, 'cm': 0.0064919161526199301, 'car': 2.1415698324597736, 'n': 1.3079979838750804, 'cbrown': 0.85853326230317983, 'psoil': 0.85742728487809516, 'cab': 49.740029038147703, 'ala': 15.085879889174436, 'cw': 0.010148735305776143, 'hspot': 0.41250691816952412}
# ({'ala': 21.811746512275406,
#   'bsoil': 0.92780684178522754,
#   'cab': 49.762985062280976,
#   'car': 1.5491913898521137,
#   'cbrown': 0.83771753093482726,
#   'cm': 0.0063385285096441693,
#   'cw': 0.010007018716533159,
#   'hspot': 0.99899999477752843,
#   'lai': 2.5122937629895548,
#   'n': 1.212666645702644,
#   'psoil': 0.59917775441340604},
#  4.1838837366286511e-16,
#  {'funcalls': 125,
#   'grad': array([[  5.16660776e-12,  -3.45445879e-09,   1.15306090e-09,
#          -4.31015761e-09,   1.08280957e-10,   2.82890792e-09,
#          -1.51790874e-08,  -2.34216215e-08,  -1.43317569e-09,
#           1.01157015e-09,   5.28320633e-10]]),
#   'task': 'CONVERGENCE: REL_REDUCTION_OF_F <= FACTR*EPSMCH',
#   'warnflag': 0})

# %%
solver2(75,test_SB,gps,b,inputs_v=inputs_v,noshow=False,train_SB=train_SB)
# Out:
# parameters2:  {'bsoil': 0.091360519209676597, 'lai': 0.35973300500333805, 'cm': 0.0087733207707764368, 'car': 3.4482048213070202, 'n': 1.4527124521181392, 'cbrown': 0.42313955524771263, 'psoil': 0.69571744728495333, 'cab': 58.978964056774252, 'ala': 82.039369681950589, 'cw': 0.024537112958777443, 'hspot': 0.79100875639024415}
# true       :  {'bsoil': 0.26284868323768862, 'lai': 0.62692210733359299, 'cm': 0.020359325295514836, 'car': 1.8324374204923517, 'n': 1.3091397277165799, 'cbrown': 0.51403485609724764, 'psoil': 0.44834147371546007, 'cab': 53.299431760953276, 'ala': 85.831542445738748, 'cw': 0.038406161283834186, 'hspot': 0.82033422914959586}
# ({'ala': 82.039369681950589,
#   'bsoil': 0.091360519209676597,
#   'cab': 58.978964056774252,
#   'car': 3.4482048213070202,
#   'cbrown': 0.42313955524771263,
#   'cm': 0.0087733207707764368,
#   'cw': 0.024537112958777443,
#   'hspot': 0.79100875639024415,
#   'lai': 0.35973300500333805,
#   'n': 1.4527124521181392,
#   'psoil': 0.69571744728495333},
#  3.2250655502341862e-15,
#  {'funcalls': 122,
#   'grad': array([[  7.56469384e-11,   2.53622708e-10,   1.34640661e-09,
#          -7.47077330e-11,  -3.16969877e-11,  -1.94258458e-08,
#           1.09347512e-08,   6.76347950e-09,   1.42161570e-09,
#           1.53368383e-08,  -2.54556066e-08]]),
#   'task': 'CONVERGENCE: REL_REDUCTION_OF_F <= FACTR*EPSMCH',
#   'warnflag': 0})

# %%
# %timeit solver2(100,test_SB,gps,b,inputs_v=inputs_v,noshow=False,train_SB=train_SB)
# Out:
# parameters2:  {'bsoil': 1.803494156561473, 'lai': 2.297178623923986, 'cm': 0.0074881778806033432, 'car': 3.0671606008606074, 'n': 1.1631060455480158, 'cbrown': 0.050779474005628863, 'psoil': 0.0036673531816873292, 'cab': 58.837118545995295, 'ala': 24.919662566955637, 'cw': 0.0057790747643533362, 'hspot': 0.029081354890520252}
# true       :  {'bsoil': 1.8830570872371115, 'lai': 1.8875339453458606, 'cm': 0.0082859595502299786, 'car': 2.5074608641165037, 'n': 1.3751123066443423, 'cbrown': 0.076246436486063995, 'psoil': 0.90165048471229814, 'cab': 70.367924725977247, 'ala': 19.827988421266181, 'cw': 0.0061820797575951724, 'hspot': 0.067088584826106246}
# parameters2:  {'bsoil': 1.803494156561473, 'lai': 2.297178623923986, 'cm': 0.0074881778806033432, 'car': 3.0671606008606074, 'n': 1.1631060455480158, 'cbrown': 0.050779474005628863, 'psoil': 0.0036673531816873292, 'cab': 58.837118545995295, 'ala': 24.919662566955637, 'cw': 0.0057790747643533362, 'hspot': 0.029081354890520252}
# true       :  {'bsoil': 1.8830570872371115, 'lai': 1.8875339453458606, 'cm': 0.0082859595502299786, 'car': 2.5074608641165037, 'n': 1.3751123066443423, 'cbrown': 0.076246436486063995, 'psoil': 0.90165048471229814, 'cab': 70.367924725977247, 'ala': 19.827988421266181, 'cw': 0.0061820797575951724, 'hspot': 0.067088584826106246}
# parameters2:  {'bsoil': 1.803494156561473, 'lai': 2.297178623923986, 'cm': 0.0074881778806033432, 'car': 3.0671606008606074, 'n': 1.1631060455480158, 'cbrown': 0.050779474005628863, 'psoil': 0.0036673531816873292, 'cab': 58.837118545995295, 'ala': 24.919662566955637, 'cw': 0.0057790747643533362, 'hspot': 0.029081354890520252}
# true       :  {'bsoil': 1.8830570872371115, 'lai': 1.8875339453458606, 'cm': 0.0082859595502299786, 'car': 2.5074608641165037, 'n': 1.3751123066443423, 'cbrown': 0.076246436486063995, 'psoil': 0.90165048471229814, 'cab': 70.367924725977247, 'ala': 19.827988421266181, 'cw': 0.0061820797575951724, 'hspot': 0.067088584826106246}
# parameters2:  {'bsoil': 1.803494156561473, 'lai': 2.297178623923986, 'cm': 0.0074881778806033432, 'car': 3.0671606008606074, 'n': 1.1631060455480158, 'cbrown': 0.050779474005628863, 'psoil': 0.0036673531816873292, 'cab': 58.837118545995295, 'ala': 24.919662566955637, 'cw': 0.0057790747643533362, 'hspot': 0.029081354890520252}
# true       :  {'bsoil': 1.8830570872371115, 'lai': 1.8875339453458606, 'cm': 0.0082859595502299786, 'car': 2.5074608641165037, 'n': 1.3751123066443423, 'cbrown': 0.076246436486063995, 'psoil': 0.90165048471229814, 'cab': 70.367924725977247, 'ala': 19.827988421266181, 'cw': 0.0061820797575951724, 'hspot': 0.067088584826106246}
# 1 loops, best of 3: 1.47 s per loop

# %%
dare = {}
dareF = []
dareD = []
nn = len(test_params['n'])/5
for i in xrange(nn):
  solved,f,d = solver2(i,test_SB,gps,b,inputs_v=inputs_v,noshow=True,noplot=True,train_SB=train_SB)
  dare = addDict(dare,solved)
  dareD.append(d);dareF.append(f)

# %%
xdare = transform(dare)
xtruth = test_params
truth = invtransform(test_params)
print xdare.keys()
good = ~np.array([dareD[j]['warnflag'] != 0 for j in xrange(nn)])
# Out:
# ['xala', 'bsoil', 'hspot', 'xcab', 'xlai', 'n', 'xcw', 'xcar', 'cbrown', 'psoil', 'xcm']

# %%
plt.scatter(xtruth['xcab'][:nn][good],xdare['xcab'][good])

# %%
plt.scatter(xtruth['xlai'][:nn][good],xdare['xlai'][good])
